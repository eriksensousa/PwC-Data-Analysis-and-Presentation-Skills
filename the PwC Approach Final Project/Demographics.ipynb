# %% [markdown]
# # Demographics

# %% [markdown]
# ***

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
from numpy import count_nonzero, median, mean
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import random


# %matplotlib inline
#sets the default autosave frequency in seconds
# %autosave 60 
sns.set_style('dark')
sns.set(font_scale=1.2)

plt.rc('axes', titlesize=9)
plt.rc('axes', labelsize=14)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format','{:.2f}'.format)

random.seed(0)
np.random.seed(0)
np.set_printoptions(suppress=True)
# Out:
# Autosaving every 60 seconds

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df = pd.read_csv("demographics.csv")

# %%
df
# Out:
#                   Location     Location2     Location3 State       County  Land Area  WaterArea  Latitude  Longitude Population Growth Rate  WhitePopulation  BlackPopulation  HispanicPopulation  AsianPopulation  HawaiianPopulation  IndianPopulation  OtherPopulation  MalePopulation  FemalePopulation  Number of Burgalaries reported  MedianAge  Crime Rate  Homicide Reported CBSA_Type  FinanceNumber Property Crime Rate Housing Construction  HouseholdsPerZipCode  AverageHouseValue  Elevation
# 0       Alabama|Abbeville     Abbeville     Abbeville     AL        Henry     107.75       3.13     31.59     -85.23                 -1.41%          2186.00          1152.00               78.00            18.00                3.00             25.00            45.00         1647.00           1745.00                            4.00      46.20          93                NaN     Metro       10020.00                42.5                0.93%               1412.00           88900.00     499.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6759 entries, 0 to 6758
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Location                        6759 non-null   object
#  1   Location2                       6759 non-null   object
#  2   Location3                       6759 non-null   object
#  3   State                           6756 non-null   object
#  4   County                          6756 non-null   object
#  5   Land Area                       6759 non-null   float64
#  6   WaterArea                       6759 non-null   float64
#  7   Latitude                        6756 non-null   float64
#  8   Longitude                       6756 non-null   float64
#  9   Population Growth Rate          6718 non-null   object
#  10  WhitePopulation                 6756 non-null   float64
#  11  BlackPopulation                 6756 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Land Area  WaterArea  Latitude  Longitude  WhitePopulation  BlackPopulation  HispanicPopulation  AsianPopulation  HawaiianPopulation  IndianPopulation  OtherPopulation  MalePopulation  FemalePopulation  Number of Burgalaries reported  MedianAge  Crime Rate  Homicide Reported  FinanceNumber  HouseholdsPerZipCode  AverageHouseValue  Elevation
# count    6759.00    6759.00   6756.00    6756.00          6756.00          6756.00             6756.00          6756.00             6756.00           6756.00          6756.00         6756.00           6756.00                         6726.00    6756.00     6759.00            1386.00        6756.00               6756.00            6756.00    6756.00
# ...

# %%
df.columns
# Out:
# Index(['Location', 'Location2', 'Location3', 'State', 'County', 'Land Area', 'WaterArea', 'Latitude', 'Longitude', 'Population Growth Rate', 'WhitePopulation', 'BlackPopulation', 'HispanicPopulation', 'AsianPopulation', 'HawaiianPopulation', 'IndianPopulation', 'OtherPopulation', 'MalePopulation', 'FemalePopulation', 'Number of Burgalaries reported', 'MedianAge', 'Crime Rate', 'Homicide Reported', 'CBSA_Type', 'FinanceNumber', 'Property Crime Rate', 'Housing Construction', 'HouseholdsPerZipCode', 'AverageHouseValue', 'Elevation'], dtype='object')

# %%
df.drop(['Location', 'Location2'], axis=1, inplace=True)

# %%
df.drop(['State', 'County', 'Land Area', 'WaterArea', 'Latitude', 'Longitude'], axis=1, inplace=True)

# %%
df.drop(['WhitePopulation', 'BlackPopulation', 'HispanicPopulation', 'AsianPopulation', 'HawaiianPopulation', 
         'IndianPopulation', 'OtherPopulation', 'MalePopulation', 'FemalePopulation'], axis=1, inplace=True)

# %%
df.drop(['MedianAge','Homicide Reported', 'CBSA_Type', 'FinanceNumber','Elevation'], axis=1, inplace=True)

# %%
df
# Out:
#          Location3 Population Growth Rate  Number of Burgalaries reported  Crime Rate Property Crime Rate Housing Construction  HouseholdsPerZipCode  AverageHouseValue
# 0       Abbeville                  -1.41%                            4.00          93                42.5                0.93%               1412.00           88900.00
# 1      Adamsville                  -2.09%                           10.00         403               186.5               -0.69%               1534.00           97100.00
# 2         Addison                  -1.64%                            1.00          32                15.5                2.64%                501.00           88700.00
# 3       Alabaster                   1.25%                           19.00         670                 306               -2.25%               4590.00          160100.00
# ...

# %%
#df.to_csv("demo2.csv", index=False)

# %% [markdown]
# #### Python code done by Dennis Lam
